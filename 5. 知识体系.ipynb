# %% [markdown]
# # 1. 金融量化投资到底需要什么知识体系
# 数据建模、数据科学

# %% [markdown]
# ## 1.1 金融相关知识
# 金融学基础 严宏
# 会计学与财务分析基础 李峰

# %% [markdown]
# ## 1.2 计算机技术相关
# Python
# 数据分析工具（Nunpy、Pandas）
# 机器学习、深度学习、强化学习

# %% [markdown]
# ## 1.3 误区
# 量化 不是 预测股票价格走势
# 数据帮助进行辅助决策

# %% [markdown]
# ## 1.4 实际项目举例

# %% [markdown]
# 场景：根据股票基本面数据与财务报表数据判断定性的交易策略。

# %% [markdown]
# 问题：某只股票与其他股票的相似性，寻找关键点
# 解决方法：

# %% [markdown]
# 第一步

# %% [markdown]
# ![image-20220325145711555.png](attachment:image-20220325145711555.png)

# %% [markdown]
# 第二步

# %% [markdown]
# ![image.png](attachment:image.png)
